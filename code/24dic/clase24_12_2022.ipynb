# %%
import pandas as pd
import numpy as np

# %%
nls97 = pd.read_csv("data/nls97.csv")
covid19= pd.read_csv("data/covidtotals.csv")

# %%
nls97.head()
# Out:
#    personid  gender  birthmonth  birthyear  highestgradecompleted  \
# 0    100061  Female           5       1980                   13.0
# 1    100139    Male           9       1983                   12.0
# 2    100284    Male          11       1984                    7.0
# 3    100292    Male           4       1982                    NaN
# 4    100583    Male           1       1980                   13.0
#
#    maritalstatus  childathome  childnotathome  wageincome  \
# 0        Married          4.0             0.0     12500.0
# 1        Married          2.0             0.0    120000.0
# 2  Never-married          1.0             0.0     58000.0
# 3            NaN          NaN             NaN         NaN
# 4        Married          4.0             0.0     30000.0
#
#          weeklyhrscomputer  ...      colenrfeb13      colenroct13  \
# 0  10 hours or more a week  ...  1. Not enrolled  1. Not enrolled
# 1      1 to 3 hours a week  ...  1. Not enrolled  1. Not enrolled
# ...

# %%
nls97.set_index("personid", inplace=True)

# %%
nls97.shape
# Out:
# (8984, 88)

# %%
nls97.index.nunique()
# Out:
# 8984

# %%
nls97.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8984 entries, 100061 to 999963
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 8984 non-null   object
#  1   birthmonth             8984 non-null   int64
#  2   birthyear              8984 non-null   int64
#  3   highestgradecompleted  6663 non-null   float64
#  4   maritalstatus          6672 non-null   object
#  5   childathome            4791 non-null   float64
#  6   childnotathome         4791 non-null   float64
#  7   wageincome             5091 non-null   float64
#  8   weeklyhrscomputer      6710 non-null   object
#  9   weeklyhrstv            6711 non-null   object
#  10  nightlyhrssleep        6706 non-null   float64
#  11  satverbal              1406 non-null   float64
#  12  satmath                1407 non-null   float64
#  13  gpaoverall             6004 non-null   float64
# ...

# %%
nls97.head(2).T
# Out:
# personid                                100061                100139
# gender                                  Female                  Male
# birthmonth                                   5                     9
# birthyear                                 1980                  1983
# highestgradecompleted                     13.0                  12.0
# maritalstatus                          Married               Married
# childathome                                4.0                   2.0
# childnotathome                             0.0                   0.0
# wageincome                             12500.0              120000.0
# weeklyhrscomputer      10 hours or more a week   1 to 3 hours a week
# weeklyhrstv              11 to 20 hours a week  3 to 10 hours a week
# nightlyhrssleep                            6.0                   8.0
# satverbal                                  NaN                   NaN
# satmath                                    NaN                   NaN
# ...

# %%
covid19.head()
# Out:
#   iso_code    lastdate     location  total_cases  total_deaths  \
# 0      AFG  2020-06-01  Afghanistan        15205           257
# 1      ALB  2020-06-01      Albania         1137            33
# 2      DZA  2020-06-01      Algeria         9394           653
# 3      AND  2020-06-01      Andorra          764            51
# 4      AGO  2020-06-01       Angola           86             4
#
#    total_cases_pm  total_deaths_pm  population  pop_density  median_age  \
# 0         390.589            6.602  38928341.0       54.422        18.6
# 1         395.093           11.467   2877800.0      104.871        38.0
# 2         214.225           14.891  43851043.0       17.348        29.1
# 3        9888.048          660.066     77265.0      163.755         NaN
# 4           2.617            0.122  32866268.0       23.890        16.8
#
#    gdp_per_capita  hosp_beds
# 0        1803.987       0.50
# 1       11803.431       2.89
# 2       13913.839       1.90
# 3             NaN        NaN
# ...

# %%
covid19= pd.read_csv("data/covidtotals.csv")

# %%
covid19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   iso_code         210 non-null    object
#  1   lastdate         210 non-null    object
#  2   location         210 non-null    object
#  3   total_cases      210 non-null    int64
#  4   total_deaths     210 non-null    int64
#  5   total_cases_pm   209 non-null    float64
#  6   total_deaths_pm  209 non-null    float64
#  7   population       210 non-null    float64
#  8   pop_density      198 non-null    float64
#  9   median_age       186 non-null    float64
#  10  gdp_per_capita   182 non-null    float64
#  11  hosp_beds        164 non-null    float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 19.8+ KB

# %%
covid19 = pd.read_csv("data/covidtotals.csv", parse_dates=["lastdate"])

# %%
covid19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   iso_code         210 non-null    object
#  1   lastdate         210 non-null    datetime64[ns]
#  2   location         210 non-null    object
#  3   total_cases      210 non-null    int64
#  4   total_deaths     210 non-null    int64
#  5   total_cases_pm   209 non-null    float64
#  6   total_deaths_pm  209 non-null    float64
#  7   population       210 non-null    float64
#  8   pop_density      198 non-null    float64
#  9   median_age       186 non-null    float64
#  10  gdp_per_capita   182 non-null    float64
#  11  hosp_beds        164 non-null    float64
# dtypes: datetime64[ns](1), float64(7), int64(2), object(2)
# memory usage: 19.8+ KB

# %%
covid19.head()
# Out:
#   iso_code   lastdate     location  total_cases  total_deaths  total_cases_pm  \
# 0      AFG 2020-06-01  Afghanistan        15205           257         390.589
# 1      ALB 2020-06-01      Albania         1137            33         395.093
# 2      DZA 2020-06-01      Algeria         9394           653         214.225
# 3      AND 2020-06-01      Andorra          764            51        9888.048
# 4      AGO 2020-06-01       Angola           86             4           2.617
#
#    total_deaths_pm  population  pop_density  median_age  gdp_per_capita  \
# 0            6.602  38928341.0       54.422        18.6        1803.987
# 1           11.467   2877800.0      104.871        38.0       11803.431
# 2           14.891  43851043.0       17.348        29.1       13913.839
# 3          660.066     77265.0      163.755         NaN             NaN
# 4            0.122  32866268.0       23.890        16.8        5819.495
#
#    hosp_beds
# 0       0.50
# 1       2.89
# 2       1.90
# ...

# %%
covid19.iso_code.nunique()
# Out:
# 210

# %%
covid19.shape
# Out:
# (210, 12)

# %%
covid19.set_index("iso_code",inplace=True)

# %%
covid19.sample(2,random_state=1).T
# Out:
# iso_code                         COG                  THA
# lastdate         2020-06-01 00:00:00  2020-06-01 00:00:00
# location                       Congo             Thailand
# total_cases                      611                 3081
# total_deaths                      20                   57
# total_cases_pm               110.727                44.14
# total_deaths_pm                3.624                0.817
# population                 5518092.0           69799978.0
# pop_density                   15.405              135.132
# median_age                      19.0                 40.1
# gdp_per_capita              4881.406            16277.671
# hosp_beds                        NaN                  2.1

# %%
nls97.loc[100292]
# Out:
# gender                              Male
# birthmonth                             4
# birthyear                           1982
# highestgradecompleted                NaN
# maritalstatus                        NaN
#                               ...
# colenroct15              1. Not enrolled
# colenrfeb16                          NaN
# colenroct16                          NaN
# colenrfeb17                          NaN
# colenroct17                          NaN
# Name: 100292, Length: 88, dtype: object

# %%
nls97.loc[100061]
# Out:
# gender                            Female
# birthmonth                             5
# birthyear                           1980
# highestgradecompleted               13.0
# maritalstatus                    Married
#                               ...
# colenroct15              1. Not enrolled
# colenrfeb16              1. Not enrolled
# colenroct16              1. Not enrolled
# colenrfeb17              1. Not enrolled
# colenroct17              1. Not enrolled
# Name: 100061, Length: 88, dtype: object

# %%
pd.set_option('display.width', 70)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 90)

# %%
nls97.loc[100061]
# Out:
# gender                                    Female
# birthmonth                                     5
# birthyear                                   1980
# highestgradecompleted                       13.0
# maritalstatus                            Married
# childathome                                  4.0
# childnotathome                               0.0
# wageincome                               12500.0
# weeklyhrscomputer        10 hours or more a week
# weeklyhrstv                11 to 20 hours a week
# nightlyhrssleep                              6.0
# satverbal                                    NaN
# satmath                                      NaN
# gpaoverall                                 306.0
# gpaenglish                                 350.0
# gpamath                                    280.0
# gpascience                                 315.0
# highestdegree                     2. High School
# govprovidejobs                               NaN
# ...

# %%
nls97.head(2).T
# Out:
# personid                                100061                100139
# gender                                  Female                  Male
# birthmonth                                   5                     9
# birthyear                                 1980                  1983
# highestgradecompleted                     13.0                  12.0
# maritalstatus                          Married               Married
# childathome                                4.0                   2.0
# childnotathome                             0.0                   0.0
# wageincome                             12500.0              120000.0
# weeklyhrscomputer      10 hours or more a week   1 to 3 hours a week
# weeklyhrstv              11 to 20 hours a week  3 to 10 hours a week
# nightlyhrssleep                            6.0                   8.0
# satverbal                                  NaN                   NaN
# satmath                                    NaN                   NaN
# ...

# %%
nls97.head(2)
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted  \
# personid
# 100061    Female           5       1980                   13.0
# 100139      Male           9       1983                   12.0
#
#          maritalstatus  childathome  childnotathome  wageincome  \
# personid
# 100061         Married          4.0             0.0     12500.0
# 100139         Married          2.0             0.0    120000.0
#
#                 weeklyhrscomputer            weeklyhrstv  ...  \
# personid                                                  ...
# 100061    10 hours or more a week  11 to 20 hours a week  ...
# 100139        1 to 3 hours a week   3 to 10 hours a week  ...
#
#               colenrfeb13      colenroct13      colenrfeb14  \
# personid
# 100061    1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100139    1. Not enrolled  1. Not enrolled  1. Not enrolled
#
#               colenroct14      colenrfeb15      colenroct15  \
# personid
# ...

# %%
nls97.columns
# Out:
# Index(['gender', 'birthmonth', 'birthyear', 'highestgradecompleted',
#        'maritalstatus', 'childathome', 'childnotathome',
#        'wageincome', 'weeklyhrscomputer', 'weeklyhrstv',
#        'nightlyhrssleep', 'satverbal', 'satmath', 'gpaoverall',
#        'gpaenglish', 'gpamath', 'gpascience', 'highestdegree',
#        'govprovidejobs', 'govpricecontrols', 'govhealthcare',
#        'govelderliving', 'govindhelp', 'govunemp', 'govincomediff',
#        'govcollegefinance', 'govdecenthousing',
#        'govprotectenvironment', 'weeksworked00', 'weeksworked01',
#        'weeksworked02', 'weeksworked03', 'weeksworked04',
#        'weeksworked05', 'weeksworked06', 'weeksworked07',
#        'weeksworked08', 'weeksworked09', 'weeksworked10',
#        'weeksworked11', 'weeksworked12', 'weeksworked13',
#        'weeksworked14', 'weeksworked15', 'weeksworked16',
#        'weeksworked17', 'colenrfeb97', 'colenroct97', 'colenrfeb98',
# ...

# %%
nls97.loc[:, nls97.dtypes=="object"] = nls97.select_dtypes(['object']).apply(lambda x: x.astype('category'))

# %%
nls97.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8984 entries, 100061 to 999963
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 8984 non-null   category
#  1   birthmonth             8984 non-null   int64
#  2   birthyear              8984 non-null   int64
#  3   highestgradecompleted  6663 non-null   float64
#  4   maritalstatus          6672 non-null   category
#  5   childathome            4791 non-null   float64
#  6   childnotathome         4791 non-null   float64
#  7   wageincome             5091 non-null   float64
#  8   weeklyhrscomputer      6710 non-null   category
#  9   weeklyhrstv            6711 non-null   category
#  10  nightlyhrssleep        6706 non-null   float64
#  11  satverbal              1406 non-null   float64
#  12  satmath                1407 non-null   float64
#  13  gpaoverall             6004 non-null   float64
# ...

# %%
gnd=nls97['gender']

# %%
gnd
# Out:
# personid
# 100061    Female
# 100139      Male
# 100284      Male
# 100292      Male
# 100583      Male
#            ...
# 999291    Female
# 999406      Male
# 999543    Female
# 999698    Female
# 999963    Female
# Name: gender, Length: 8984, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
type(gnd)
# Out:
# pandas.core.series.Series

# %%
gnd=nls97[['gender']]

# %%
type(gnd)
# Out:
# pandas.core.frame.DataFrame

# %%
gnd.loc[100061]
# Out:
# gender    Female
# Name: 100061, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
gnd.dtypes
# Out:
# gender    category
# dtype: object

# %%
gnd=nls97.iloc[:,[0]]

# %%
gnd
# Out:
#           gender
# personid
# 100061    Female
# 100139      Male
# 100284      Male
# 100292      Male
# 100583      Male
# ...          ...
# 999291    Female
# 999406      Male
# 999543    Female
# 999698    Female
# 999963    Female
#
# [8984 rows x 1 columns]

# %%
gnd = nls97.loc[:,["gender"]]

# %%
gnd
# Out:
#           gender
# personid
# 100061    Female
# 100139      Male
# 100284      Male
# 100292      Male
# 100583      Male
# ...          ...
# 999291    Female
# 999406      Male
# 999543    Female
# 999698    Female
# 999963    Female
#
# [8984 rows x 1 columns]

# %%
subCols= nls97[["gender","maritalstatus","highestgradecompleted"]]

# %%
subCols
# Out:
#           gender  maritalstatus  highestgradecompleted
# personid
# 100061    Female        Married                   13.0
# 100139      Male        Married                   12.0
# 100284      Male  Never-married                    7.0
# 100292      Male            NaN                    NaN
# 100583      Male        Married                   13.0
# ...          ...            ...                    ...
# 999291    Female        Married                   16.0
# 999406      Male  Never-married                   14.0
# 999543    Female       Divorced                   12.0
# 999698    Female  Never-married                   12.0
# 999963    Female        Married                   17.0
#
# [8984 rows x 3 columns]

# %%
subCols.shape
# Out:
# (8984, 3)

# %%
nls97.shape
# Out:
# (8984, 88)

# %%
subCols= nls97.loc[:,["gender","maritalstatus","highestgradecompleted"]]

# %%
subCols.shape
# Out:
# (8984, 3)

# %%
subCols= nls97.iloc[:,[0,4,3]]

# %%
subCols.shape
# Out:
# (8984, 3)

# %%
subCols.head()
# Out:
#           gender  maritalstatus  highestgradecompleted
# personid
# 100061    Female        Married                   13.0
# 100139      Male        Married                   12.0
# 100284      Male  Never-married                    7.0
# 100292      Male            NaN                    NaN
# 100583      Male        Married                   13.0

# %%
nls97.columns
# Out:
# Index(['gender', 'birthmonth', 'birthyear', 'highestgradecompleted',
#        'maritalstatus', 'childathome', 'childnotathome',
#        'wageincome', 'weeklyhrscomputer', 'weeklyhrstv',
#        'nightlyhrssleep', 'satverbal', 'satmath', 'gpaoverall',
#        'gpaenglish', 'gpamath', 'gpascience', 'highestdegree',
#        'govprovidejobs', 'govpricecontrols', 'govhealthcare',
#        'govelderliving', 'govindhelp', 'govunemp', 'govincomediff',
#        'govcollegefinance', 'govdecenthousing',
#        'govprotectenvironment', 'weeksworked00', 'weeksworked01',
#        'weeksworked02', 'weeksworked03', 'weeksworked04',
#        'weeksworked05', 'weeksworked06', 'weeksworked07',
#        'weeksworked08', 'weeksworked09', 'weeksworked10',
#        'weeksworked11', 'weeksworked12', 'weeksworked13',
#        'weeksworked14', 'weeksworked15', 'weeksworked16',
#        'weeksworked17', 'colenrfeb97', 'colenroct97', 'colenrfeb98',
# ...

# %%
seleccion=['gender','maritalstatus','highestgradecompleted','wageincome','gpaoverall','weeksworked17','colenroct17']

# %%
subCols2=nls97[seleccion]

# %%
subCols2.head()
# Out:
#           gender  maritalstatus  highestgradecompleted  wageincome  \
# personid
# 100061    Female        Married                   13.0     12500.0
# 100139      Male        Married                   12.0    120000.0
# 100284      Male  Never-married                    7.0     58000.0
# 100292      Male            NaN                    NaN         NaN
# 100583      Male        Married                   13.0     30000.0
#
#           gpaoverall  weeksworked17      colenroct17
# personid
# 100061         306.0           48.0  1. Not enrolled
# 100139           NaN           52.0  1. Not enrolled
# 100284           NaN            0.0  1. Not enrolled
# 100292         345.0            NaN              NaN
# 100583         291.0           52.0  1. Not enrolled

# %%
subCols2.shape
# Out:
# (8984, 7)

# %%
subCols2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8984 entries, 100061 to 999963
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 8984 non-null   category
#  1   maritalstatus          6672 non-null   category
#  2   highestgradecompleted  6663 non-null   float64
#  3   wageincome             5091 non-null   float64
#  4   gpaoverall             6004 non-null   float64
#  5   weeksworked17          6670 non-null   float64
#  6   colenroct17            6734 non-null   category
# dtypes: category(3), float64(4)
# memory usage: 635.8 KB

# %%
#Filtros para seleccion de columna

filtrada=nls97.filter(like="weeksworked")

# %%
filtrada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8984 entries, 100061 to 999963
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   weeksworked00  8603 non-null   float64
#  1   weeksworked01  8564 non-null   float64
#  2   weeksworked02  8556 non-null   float64
#  3   weeksworked03  8490 non-null   float64
#  4   weeksworked04  8458 non-null   float64
#  5   weeksworked05  8403 non-null   float64
#  6   weeksworked06  8340 non-null   float64
#  7   weeksworked07  8272 non-null   float64
#  8   weeksworked08  8186 non-null   float64
#  9   weeksworked09  8146 non-null   float64
#  10  weeksworked10  8054 non-null   float64
#  11  weeksworked11  7968 non-null   float64
#  12  weeksworked12  7747 non-null   float64
#  13  weeksworked13  7680 non-null   float64
#  14  weeksworked14  7612 non-null   float64
#  15  weeksworked15  7389 non-null   float64
#  16  weeksworked16  7068 non-null   float64
# ...

# %%
filtrada.head(2)
# Out:
#           weeksworked00  weeksworked01  weeksworked02  \
# personid
# 100061             46.0           52.0           52.0
# 100139              5.0           49.0           52.0
#
#           weeksworked03  weeksworked04  weeksworked05  \
# personid
# 100061             48.0           52.0           53.0
# 100139             52.0           52.0           53.0
#
#           weeksworked06  weeksworked07  weeksworked08  \
# personid
# 100061             52.0           52.0           39.0
# 100139             52.0           52.0           52.0
#
#           weeksworked09  weeksworked10  weeksworked11  \
# personid
# 100061             40.0           52.0           53.0
# 100139             52.0           52.0           53.0
#
#           weeksworked12  weeksworked13  weeksworked14  \
# personid
# 100061             40.0           52.0           52.0
# 100139             52.0           52.0           52.0
#
#           weeksworked15  weeksworked16  weeksworked17
# personid
# ...

# %%
filtrada.head(2).T
# Out:
# personid       100061  100139
# weeksworked00    46.0     5.0
# weeksworked01    52.0    49.0
# weeksworked02    52.0    52.0
# weeksworked03    48.0    52.0
# weeksworked04    52.0    52.0
# weeksworked05    53.0    53.0
# weeksworked06    52.0    52.0
# weeksworked07    52.0    52.0
# weeksworked08    39.0    52.0
# weeksworked09    40.0    52.0
# weeksworked10    52.0    52.0
# weeksworked11    53.0    53.0
# weeksworked12    40.0    52.0
# weeksworked13    52.0    52.0
# weeksworked14    52.0    52.0
# weeksworked15    52.0    52.0
# weeksworked16    48.0    53.0
# weeksworked17    48.0    52.0

# %%
categoricos = nls97.select_dtypes("category")

# %%
numericos = nls97.select_dtypes("number")

# %%
categoricos.head(2).T
# Out:
# personid                                100061                100139
# gender                                  Female                  Male
# maritalstatus                          Married               Married
# weeklyhrscomputer      10 hours or more a week   1 to 3 hours a week
# weeklyhrstv              11 to 20 hours a week  3 to 10 hours a week
# highestdegree                   2. High School        2. High School
# govprovidejobs                             NaN                   NaN
# govpricecontrols                           NaN                   NaN
# govhealthcare                              NaN                   NaN
# govelderliving                             NaN                   NaN
# govindhelp                                 NaN                   NaN
# govunemp                                   NaN                   NaN
# govincomediff                              NaN                   NaN
# govcollegefinance                          NaN                   NaN
# ...

# %%
numericos.head(2).T
# Out:
# personid                100061    100139
# birthmonth                 5.0       9.0
# birthyear               1980.0    1983.0
# highestgradecompleted     13.0      12.0
# childathome                4.0       2.0
# childnotathome             0.0       0.0
# wageincome             12500.0  120000.0
# nightlyhrssleep            6.0       8.0
# satverbal                  NaN       NaN
# satmath                    NaN       NaN
# gpaoverall               306.0       NaN
# gpaenglish               350.0       NaN
# gpamath                  280.0       NaN
# gpascience               315.0       NaN
# weeksworked00             46.0       5.0
# weeksworked01             52.0      49.0
# weeksworked02             52.0      52.0
# weeksworked03             48.0      52.0
# weeksworked04             52.0      52.0
# weeksworked05             53.0      53.0
# weeksworked06             52.0      52.0
# weeksworked07             52.0      52.0
# weeksworked08             39.0      52.0
# ...

# %%
numericos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8984 entries, 100061 to 999963
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   birthmonth             8984 non-null   int64
#  1   birthyear              8984 non-null   int64
#  2   highestgradecompleted  6663 non-null   float64
#  3   childathome            4791 non-null   float64
#  4   childnotathome         4791 non-null   float64
#  5   wageincome             5091 non-null   float64
#  6   nightlyhrssleep        6706 non-null   float64
#  7   satverbal              1406 non-null   float64
#  8   satmath                1407 non-null   float64
#  9   gpaoverall             6004 non-null   float64
#  10  gpaenglish             5798 non-null   float64
#  11  gpamath                5766 non-null   float64
#  12  gpascience             5684 non-null   float64
#  13  weeksworked00          8603 non-null   float64
# ...

# %%
categoricos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8984 entries, 100061 to 999963
# Data columns (total 57 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 8984 non-null   category
#  1   maritalstatus          6672 non-null   category
#  2   weeklyhrscomputer      6710 non-null   category
#  3   weeklyhrstv            6711 non-null   category
#  4   highestdegree          8953 non-null   category
#  5   govprovidejobs         1833 non-null   category
#  6   govpricecontrols       1859 non-null   category
#  7   govhealthcare          1874 non-null   category
#  8   govelderliving         1872 non-null   category
#  9   govindhelp             1815 non-null   category
#  10  govunemp               1811 non-null   category
#  11  govincomediff          1775 non-null   category
#  12  govcollegefinance      1875 non-null   category
#  13  govdecenthousing       1847 non-null   category
# ...

# %%
numericos = nls97.select_dtypes(include=["number"])

# %%
numericos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8984 entries, 100061 to 999963
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   birthmonth             8984 non-null   int64
#  1   birthyear              8984 non-null   int64
#  2   highestgradecompleted  6663 non-null   float64
#  3   childathome            4791 non-null   float64
#  4   childnotathome         4791 non-null   float64
#  5   wageincome             5091 non-null   float64
#  6   nightlyhrssleep        6706 non-null   float64
#  7   satverbal              1406 non-null   float64
#  8   satmath                1407 non-null   float64
#  9   gpaoverall             6004 non-null   float64
#  10  gpaenglish             5798 non-null   float64
#  11  gpamath                5766 non-null   float64
#  12  gpascience             5684 non-null   float64
#  13  weeksworked00          8603 non-null   float64
# ...

# %%
nls97.columns
# Out:
# Index(['gender', 'birthmonth', 'birthyear', 'highestgradecompleted',
#        'maritalstatus', 'childathome', 'childnotathome',
#        'wageincome', 'weeklyhrscomputer', 'weeklyhrstv',
#        'nightlyhrssleep', 'satverbal', 'satmath', 'gpaoverall',
#        'gpaenglish', 'gpamath', 'gpascience', 'highestdegree',
#        'govprovidejobs', 'govpricecontrols', 'govhealthcare',
#        'govelderliving', 'govindhelp', 'govunemp', 'govincomediff',
#        'govcollegefinance', 'govdecenthousing',
#        'govprotectenvironment', 'weeksworked00', 'weeksworked01',
#        'weeksworked02', 'weeksworked03', 'weeksworked04',
#        'weeksworked05', 'weeksworked06', 'weeksworked07',
#        'weeksworked08', 'weeksworked09', 'weeksworked10',
#        'weeksworked11', 'weeksworked12', 'weeksworked13',
#        'weeksworked14', 'weeksworked15', 'weeksworked16',
#        'weeksworked17', 'colenrfeb97', 'colenroct97', 'colenrfeb98',
# ...

# %%
demograficos=["gender","birthmonth","birthyear"]

datos_escolares=['satverbal', 'satmath', 'gpaoverall',
       'gpaenglish', 'gpamath', 'gpascience']

datosgov=['govprovidejobs', 'govpricecontrols', 'govhealthcare',
       'govelderliving', 'govindhelp', 'govunemp', 'govincomediff',
       'govcollegefinance', 'govdecenthousing']

demograficos_adulto=["highestgradecompleted","maritalstatus","childathome","childnotathome","wageincome","weeklyhrscomputer",'weeklyhrstv',
       'nightlyhrssleep',"highestdegree"]

weeks=[ 'weeksworked00', 'weeksworked01',
       'weeksworked02', 'weeksworked03', 'weeksworked04',
       'weeksworked05', 'weeksworked06', 'weeksworked07',
       'weeksworked08', 'weeksworked09', 'weeksworked10',
       'weeksworked11', 'weeksworked12', 'weeksworked13',
       'weeksworked14', 'weeksworked15', 'weeksworked16',
       'weeksworked17']

colenr=['colenrfeb97', 'colenroct97', 'colenrfeb98',
       'colenroct98', 'colenrfeb99', 'colenroct99', 'colenrfeb00',
       'colenroct00', 'colenrfeb01', 'colenroct01', 'colenrfeb02',
       'colenroct02', 'colenrfeb03', 'colenroct03', 'colenrfeb04',
       'colenroct04', 'colenrfeb05', 'colenroct05', 'colenrfeb06',
       'colenroct06', 'colenrfeb07', 'colenroct07', 'colenrfeb08',
       'colenroct08', 'colenrfeb09', 'colenroct09', 'colenrfeb10',
       'colenroct10', 'colenrfeb11', 'colenroct11', 'colenrfeb12',
       'colenroct12', 'colenrfeb13', 'colenroct13', 'colenrfeb14',
       'colenroct14', 'colenrfeb15', 'colenroct15', 'colenrfeb16',
       'colenroct16', 'colenrfeb17', 'colenroct17']

# %%
nls97ordenado= nls97[demograficos_adulto + demograficos + datos_escolares + datosgov + weeks + colenr]

# %%
nls97ordenado.head(1).T
# Out:
# personid                                100061
# highestgradecompleted                     13.0
# maritalstatus                          Married
# childathome                                4.0
# childnotathome                             0.0
# wageincome                             12500.0
# weeklyhrscomputer      10 hours or more a week
# weeklyhrstv              11 to 20 hours a week
# nightlyhrssleep                            6.0
# highestdegree                   2. High School
# gender                                  Female
# birthmonth                                   5
# birthyear                                 1980
# satverbal                                  NaN
# satmath                                    NaN
# gpaoverall                               306.0
# gpaenglish                               350.0
# gpamath                                  280.0
# gpascience                               315.0
# govprovidejobs                             NaN
# ...

# %%
nls97.head(1).T
# Out:
# personid                                100061
# gender                                  Female
# birthmonth                                   5
# birthyear                                 1980
# highestgradecompleted                     13.0
# maritalstatus                          Married
# childathome                                4.0
# childnotathome                             0.0
# wageincome                             12500.0
# weeklyhrscomputer      10 hours or more a week
# weeklyhrstv              11 to 20 hours a week
# nightlyhrssleep                            6.0
# satverbal                                  NaN
# satmath                                    NaN
# gpaoverall                               306.0
# gpaenglish                               350.0
# gpamath                                  280.0
# gpascience                               315.0
# highestdegree                   2. High School
# govprovidejobs                             NaN
# ...

# %%
nls97= nls97[demograficos_adulto + demograficos + datos_escolares + datosgov + weeks + colenr]

# %%
nls97.head(2).T
# Out:
# personid                                100061                100139
# highestgradecompleted                     13.0                  12.0
# maritalstatus                          Married               Married
# childathome                                4.0                   2.0
# childnotathome                             0.0                   0.0
# wageincome                             12500.0              120000.0
# weeklyhrscomputer      10 hours or more a week   1 to 3 hours a week
# weeklyhrstv              11 to 20 hours a week  3 to 10 hours a week
# nightlyhrssleep                            6.0                   8.0
# highestdegree                   2. High School        2. High School
# gender                                  Female                  Male
# birthmonth                                   5                     9
# birthyear                                 1980                  1983
# satverbal                                  NaN                   NaN
# ...

# %%
nls97.dtypes
# Out:
# highestgradecompleted     float64
# maritalstatus            category
# childathome               float64
# childnotathome            float64
# wageincome                float64
# weeklyhrscomputer        category
# weeklyhrstv              category
# nightlyhrssleep           float64
# highestdegree            category
# gender                   category
# birthmonth                  int64
# birthyear                   int64
# satverbal                 float64
# satmath                   float64
# gpaoverall                float64
# gpaenglish                float64
# gpamath                   float64
# gpascience                float64
# govprovidejobs           category
# govpricecontrols         category
# govhealthcare            category
# govelderliving           category
# govindhelp               category
# govunemp                 category
# govincomediff            category
# govcollegefinance        category
# govdecenthousing         category
# ...

# %%
nls97.select_dtypes(exclude=["category"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8984 entries, 100061 to 999963
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   highestgradecompleted  6663 non-null   float64
#  1   childathome            4791 non-null   float64
#  2   childnotathome         4791 non-null   float64
#  3   wageincome             5091 non-null   float64
#  4   nightlyhrssleep        6706 non-null   float64
#  5   birthmonth             8984 non-null   int64
#  6   birthyear              8984 non-null   int64
#  7   satverbal              1406 non-null   float64
#  8   satmath                1407 non-null   float64
#  9   gpaoverall             6004 non-null   float64
#  10  gpaenglish             5798 non-null   float64
#  11  gpamath                5766 non-null   float64
#  12  gpascience             5684 non-null   float64
#  13  weeksworked00          8603 non-null   float64
# ...

# %%
nls97.filter(regex="home")
# Out:
#           childathome  childnotathome
# personid
# 100061            4.0             0.0
# 100139            2.0             0.0
# 100284            1.0             0.0
# 100292            NaN             NaN
# 100583            4.0             0.0
# ...               ...             ...
# 999291            NaN             NaN
# 999406            NaN             NaN
# 999543            2.0             0.0
# 999698            5.0             0.0
# 999963            2.0             0.0
#
# [8984 rows x 2 columns]

# %%
nls97.filter(regex="income")
# Out:
#           wageincome govincomediff
# personid
# 100061       12500.0           NaN
# 100139      120000.0           NaN
# 100284       58000.0           NaN
# 100292           NaN           NaN
# 100583       30000.0           NaN
# ...              ...           ...
# 999291       35000.0           NaN
# 999406      116000.0           NaN
# 999543           NaN           NaN
# 999698           NaN           NaN
# 999963       50000.0           NaN
#
# [8984 rows x 2 columns]
